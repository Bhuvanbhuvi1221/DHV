# %%
import pandas as pd

# %%
data=np.random.random((13,16))
plt.imshow(data,cmap="viridis")
plt.title("2d Heat map")
plt.colorbar()
plt.show()

# %%
import seaborn as sns
data=np.random.randint(low=0,high=100,size=(12,12))
hm=sns.heatmap(data=data,annot=True)
plt.show()
